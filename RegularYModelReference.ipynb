# %%
from google.colab import drive
import os
drive.mount("/content/drive/")

mypath = "drive/My Drive/CS598DLHProject"
os.listdir(mypath)
# Out:
# Mounted at /content/drive/
# ['data',
#  'BOTKeras.ipynb',
#  'CNNModel.ipynb',
#  'CNN3Layer.ipynb',
#  'Reference',
#  'storedModels',
#  '.ipynb_checkpoints',
#  'Preprocess.ipynb',
#  'BOTModel.ipynb',
#  'BOTModelReference.ipynb',
#  'RegularYModelReference.ipynb']

# %%
# Already unzipped. Not required

# !unzip drive/My\ Drive/CS598DLHProject/data/original_paper_data/data.npz.zip -d drive/My\ Drive/CS598DLHProject/data/original_paper_data/
# Out:
# Archive:  drive/My Drive/CS598DLHProject/data/original_paper_data/data.npz.zip
#   inflating: drive/My Drive/CS598DLHProject/data/original_paper_data/data.npz
#   inflating: drive/My Drive/CS598DLHProject/data/original_paper_data/__MACOSX/._data.npz

# %%
# Used to convert input data data.npz into x,cats,rolled,regular but not required now

# import gzip
# import pickle as pkl
# import gc

# import numpy as np

# DATA_DIR = mypath + "/data/"

# DATA_PATH = DATA_DIR + "preprocessed_3004/"
# DATA_NPZ_FILE = f'{DATA_PATH}data.npz'

# print ('reading from saved file Data.npz: ', DATA_NPZ_FILE)
# data = np.load(DATA_NPZ_FILE)
# lst = data.files
# for item in lst:
#     print(item)
#     # print(data[item])

# print("done")
# x = data['x']
# cats = data['cats']
# y_rolled = data['rol_y']
# y_full = data['reg_y']

# print(x.shape)
# print(cats.shape)
# print(y_rolled.shape)
# print(y_full.shape)
# Out:
# reading from saved file Data.npz:  drive/My Drive/CS598DLHProject/data/preprocessed_3004/data.npz
# x
# cats
# reg_y
# rol_y
# done
# (399623, 2199)
# (399623, 15)
# (399623, 781)
# (399623, 4103)

# %%
# Temporary block to convert data.npz into train/val/test

# texts = x
# texts_categories = cats
# regular_labels = y_full
# rolled_labels = y_rolled

# # Split
# s1 = int(.64 * len(texts))
# s2 = int(.8 * len(texts))
# x_train, x_val, x_test = np.split(texts, [s1, s2])
# cats_train, cats_val, cats_test = np.split(texts_categories, [s1, s2])
# reg_y_train, reg_y_val, reg_y_test = np.split(regular_labels, [s1, s2])
# rol_y_train, rol_y_val, rol_y_test = np.split(rolled_labels, [s1, s2])

# np.savez(f'{DATA_PATH}dataTrainValTest.npz',
#           x_train=x_train, x_val=x_val, x_test=x_test,
#           cats_train=cats_train, cats_val=cats_val, cats_test=cats_test,
#           reg_y_train=reg_y_train, reg_y_val=reg_y_val, reg_y_test=reg_y_test,
#           rol_y_train=rol_y_train, rol_y_val=rol_y_val, rol_y_test=rol_y_test)

# %%
#Divide dataset into 5 parts

# import gzip
# import pickle as pkl
# import gc

# import numpy as np

# DATA_DIR = mypath + "/data/"

# DATA_PATH = DATA_DIR + "preprocessed_3004/"
# DATA_NPZ_FILE = f'{DATA_PATH}dataTrainValTest.npz'

# print ('reading from saved file dataTrainValTest.npz: ', DATA_NPZ_FILE)
# data = np.load(DATA_NPZ_FILE)
# lst = data.files
# for item in lst:
#     print(item)


# x_train = data['x_train']
# x_val = data['x_val']
# x_test = data['x_test']

# rol_y_train = data['rol_y_train']
# rol_y_val = data['rol_y_val']
# rol_y_test = data['rol_y_test']

# reg_y_train = data['reg_y_train']
# reg_y_val = data['reg_y_val']
# reg_y_test = data['reg_y_test']

# print('x_train: ' , x_train.shape)
# print('x_val: ', x_val.shape)
# print('x_test: ', x_test.shape)

# print('rol_y_train: ', rol_y_train.shape)
# print('rol_y_val: ', rol_y_val.shape)
# print('rol_y_test: ', rol_y_test.shape)

# print('y_train: ', reg_y_train.shape)
# print('y_val: ', reg_y_val.shape)
# print('reg_y_test: ', reg_y_test.shape)

# total_values = 399623
# total_values_val = 63940
# i = 0
# ratio = 0.2

# print ("Storing results for train - i=" + str(i) + " - " + str(int(i*ratio*total_values)) + " to " + str(int((i+1)*ratio*total_values)))
# print ("Storing results for test i=" + str(i) + " - " + str(int(i*ratio*total_values_val)) + " to " + str(int((i+1)*ratio*total_values_val)))

# np.savez(f'{DATA_PATH}dataTrainValTestSet1.npz',
#           x_train=x_train[int(i*ratio*total_values):int((i+1)*ratio*total_values)],
#           x_val=x_val[int(i*ratio*total_values_val):int((i+1)*ratio*total_values_val)],
#           x_test=x_test,
#           reg_y_train=reg_y_train[int(i*ratio*total_values):int((i+1)*ratio*total_values)],
#           reg_y_val=reg_y_val[int(i*ratio*total_values_val):int((i+1)*ratio*total_values_val)],
#           reg_y_test=reg_y_test,
#           rol_y_train=rol_y_train[int(i*ratio*total_values):int((i+1)*ratio*total_values)],
#           rol_y_val=rol_y_val[int(i*ratio*total_values_val):int((i+1)*ratio*total_values_val)],
#           rol_y_test=rol_y_test)

# i = i + 1
# print ("Storing results for i=" + str(i) + " - " + str(int(i*ratio*total_values)) + " to " + str(int((i+1)*ratio*total_values)))
# print ("Storing results for i=" + str(i) + " - " + str(int(i*ratio*total_values_val)) + " to " + str(int((i+1)*ratio*total_values_val)))

# np.savez(f'{DATA_PATH}dataTrainValTestSet2.npz',
#           x_train=x_train[int(i*ratio*total_values):int((i+1)*ratio*total_values)],
#           x_val=x_val[int(i*ratio*total_values_val):int((i+1)*ratio*total_values_val)],
#           x_test=x_test,
#           reg_y_train=reg_y_train[int(i*ratio*total_values):int((i+1)*ratio*total_values)],
#           reg_y_val=reg_y_val[int(i*ratio*total_values_val):int((i+1)*ratio*total_values_val)],
#           reg_y_test=reg_y_test,
#           rol_y_train=rol_y_train[int(i*ratio*total_values):int((i+1)*ratio*total_values)],
#           rol_y_val=rol_y_val[int(i*ratio*total_values_val):int((i+1)*ratio*total_values_val)],
#           rol_y_test=rol_y_test)

# i = i + 1
# print ("Storing results for i=" + str(i) + " - " + str(int(i*ratio*total_values)) + " to " + str(int((i+1)*ratio*total_values)))
# print ("Storing results for i=" + str(i) + " - " + str(int(i*ratio*total_values_val)) + " to " + str(int((i+1)*ratio*total_values_val)))


# np.savez(f'{DATA_PATH}dataTrainValTestSet3.npz',
#           x_train=x_train[int(i*ratio*total_values):int((i+1)*ratio*total_values)],
#           x_val=x_val[int(i*ratio*total_values_val):int((i+1)*ratio*total_values_val)],
#           x_test=x_test,
#           reg_y_train=reg_y_train[int(i*ratio*total_values):int((i+1)*ratio*total_values)],
#           reg_y_val=reg_y_val[int(i*ratio*total_values_val):int((i+1)*ratio*total_values_val)],
#           reg_y_test=reg_y_test,
#           rol_y_train=rol_y_train[int(i*ratio*total_values):int((i+1)*ratio*total_values)],
#           rol_y_val=rol_y_val[int(i*ratio*total_values_val):int((i+1)*ratio*total_values_val)],
#           rol_y_test=rol_y_test)

# i = i + 1
# print ("Storing results for i=" + str(i) + " - " + str(int(i*ratio*total_values)) + " to " + str(int((i+1)*ratio*total_values)))
# print ("Storing results for i=" + str(i) + " - " + str(int(i*ratio*total_values_val)) + " to " + str(int((i+1)*ratio*total_values_val)))


# np.savez(f'{DATA_PATH}dataTrainValTestSet4.npz',
#           x_train=x_train[int(i*ratio*total_values):int((i+1)*ratio*total_values)],
#           x_val=x_val[int(i*ratio*total_values_val):int((i+1)*ratio*total_values_val)],
#           x_test=x_test,
#           reg_y_train=reg_y_train[int(i*ratio*total_values):int((i+1)*ratio*total_values)],
#           reg_y_val=reg_y_val[int(i*ratio*total_values_val):int((i+1)*ratio*total_values_val)],
#           reg_y_test=reg_y_test,
#           rol_y_train=rol_y_train[int(i*ratio*total_values):int((i+1)*ratio*total_values)],
#           rol_y_val=rol_y_val[int(i*ratio*total_values_val):int((i+1)*ratio*total_values_val)],
#           rol_y_test=rol_y_test)

# i = i + 1
# print ("Storing results for i=" + str(i) + " - " + str(int(i*ratio*total_values)) + " to " + str(int((i+1)*ratio*total_values)))
# print ("Storing results for i=" + str(i) + " - " + str(int(i*ratio*total_values_val)) + " to " + str(int((i+1)*ratio*total_values_val)))


# np.savez(f'{DATA_PATH}dataTrainValTestSet5.npz',
#           x_train=x_train[int(i*ratio*total_values):],
#           x_val=x_val[int(i*ratio*total_values_val):],
#           x_test=x_test,
#           reg_y_train=reg_y_train[int(i*ratio*total_values):],
#           reg_y_val=reg_y_val[int(i*ratio*total_values_val):],
#           reg_y_test=reg_y_test,
#           rol_y_train=rol_y_train[int(i*ratio*total_values):],
#           rol_y_val=rol_y_val[int(i*ratio*total_values_val):],
#           rol_y_test=rol_y_test)
# Out:
# reading from saved file dataTrainValTest.npz:  drive/My Drive/CS598DLHProject/data/preprocessed_3004/dataTrainValTest.npz
# x_train
# x_val
# x_test
# cats_train
# cats_val
# cats_test
# reg_y_train
# reg_y_val
# reg_y_test
# rol_y_train
# rol_y_val
# rol_y_test
# x_train:  (255758, 2199)
# x_val:  (63940, 2199)
# x_test:  (79925, 2199)
# rol_y_train:  (255758, 781)
# rol_y_val:  (63940, 781)
# rol_y_test:  (79925, 781)
# y_train:  (255758, 4103)
# y_val:  (63940, 4103)
# reg_y_test:  (79925, 4103)
# Storing results for train - i=0 - 0 to 79924
# Storing results for test i=0 - 0 to 12788
# Storing results for i=1 - 79924 to 159849
# Storing results for i=1 - 12788 to 25576
# Storing results for i=2 - 159849 to 239773
# Storing results for i=2 - 25576 to 38364
# Storing results for i=3 - 239773 to 319698
# Storing results for i=3 - 38364 to 51152
# Storing results for i=4 - 319698 to 399623
# Storing results for i=4 - 51152 to 63940

# %% [markdown]
# # CNN

# %%
# Fetch Full dataset

# import gzip
# import pickle as pkl
# import gc

# import numpy as np

# DATA_DIR = mypath + "/data/"

# DATA_PATH = DATA_DIR + "preprocessed_3004/"
# DATA_NPZ_FILE = f'{DATA_PATH}dataTrainValTest.npz'

# print ('reading from saved file dataTrainValTest.npz: ', DATA_NPZ_FILE)
# data = np.load(DATA_NPZ_FILE)
# lst = data.files
# for item in lst:
#     print(item)
#     # print(data[item])

# # Total values: 399623
# total_values = 399623
# i = 1
# ratio = 0.2

# print("done")
# x_train_load = data['x_train'][int(i*ratio*total_values):int((i+1)*ratio*total_values)]
# x_val_load = data['x_val']
# # x_test = data['x_test']

# ratio = 0.5
# x_train = x_train_load
# # [:int(ratio*x_train_load.shape[0])]
# x_val = x_val_load
# # [:int(ratio*x_val_load.shape[0])]
# # x_test = x_test

# del x_train_load
# del x_val_load

# print('x_train: ' , x_train.shape)
# print('x_val: ', x_val.shape)
# # print('x_test: ', x_test.shape)


# # cats_train = data['cats_train']
# # cats_val = data['cats_val']
# # cats_test = data['cats_test']

# # print('cats_train: ',  cats_train.shape)
# # print('cats_val: ', cats_val.shape)
# # print('cats_test: ', cats_test.shape)

# # rol_y_train = data['rol_y_train']
# # rol_y_val = data['rol_y_val']
# # rol_y_test = data['rol_y_test']

# # print('rol_y_train: ', rol_y_train.shape)
# # print('rol_y_val: ', rol_y_val.shape)
# # print('rol_y_test: ', rol_y_test.shape)

# # y_train = rol_y_train
# # y_val = rol_y_val
# # y_test = rol_y_test


# reg_y_train = data['reg_y_train'][int(i*ratio*total_values):int((i+1)*ratio*total_values)]
# reg_y_val = data['reg_y_val']
# # reg_y_test = data['reg_y_test']


# y_train = reg_y_train
# # [:int(ratio*reg_y_train.shape[0])]
# y_val = reg_y_val
# # [:int(ratio*reg_y_val.shape[0])]
# # y_test = reg_y_test

# print('y_train: ', y_train.shape)
# print('y_val: ', y_val.shape)
# # print('reg_y_test: ', reg_y_test.shape)

# del data
# del lst
# del reg_y_train
# del reg_y_val
# # del reg_y_test


# gc.collect()

# # class GarbageCollectorCallback(tf.keras.callbacks.Callback):
# #     def on_epoch_end(self, epoch, logs=None):
# #         gc.collect()
# Out:
# reading from saved file dataTrainValTest.npz:  drive/My Drive/CS598DLHProject/data/preprocessed_3004/dataTrainValTest.npz
# x_train
# x_val
# x_test
# cats_train
# cats_val
# cats_test
# reg_y_train
# reg_y_val
# reg_y_test
# rol_y_train
# rol_y_val
# rol_y_test
# done
# x_train:  (79925, 2199)
# x_val:  (63940, 2199)
# y_train:  (55947, 4103)
# y_val:  (63940, 4103)
# 24

# %% [markdown]
# ### Set 1

# %%
# import gzip
# import pickle as pkl
# import gc

# import numpy as np

# DATA_DIR = mypath + "/data/"

# DATA_PATH = DATA_DIR + "preprocessed_3004/"
# DATA_NPZ_FILE = f'{DATA_PATH}dataTrainValTestSet1.npz'

# print ('reading from saved file: ', DATA_NPZ_FILE)
# data = np.load(DATA_NPZ_FILE)
# lst = data.files
# for item in lst:
#     print(item)

# print("done")
# x_train_load = data['x_train']
# x_val_load = data['x_val']
# # x_test = data['x_test']

# x_train = x_train_load
# x_val = x_val_load
# # x_test = x_test

# del x_train_load
# del x_val_load

# print('x_train: ' , x_train.shape)
# print('x_val: ', x_val.shape)
# # print('x_test: ', x_test.shape)

# # rol_y_train = data['rol_y_train']
# # rol_y_val = data['rol_y_val']
# # rol_y_test = data['rol_y_test']

# # print('rol_y_train: ', rol_y_train.shape)
# # print('rol_y_val: ', rol_y_val.shape)
# # print('rol_y_test: ', rol_y_test.shape)

# # y_train = rol_y_train
# # y_val = rol_y_val
# # y_test = rol_y_test


# reg_y_train = data['reg_y_train']
# reg_y_val = data['reg_y_val']
# # reg_y_test = data['reg_y_test']


# y_train = reg_y_train
# y_val = reg_y_val
# # y_test = reg_y_test

# print('y_train: ', y_train.shape)
# print('y_val: ', y_val.shape)
# # print('reg_y_test: ', reg_y_test.shape)

# del data
# del lst
# del reg_y_train
# del reg_y_val
# # del reg_y_test


# gc.collect()
# Out:
# reading from saved file:  drive/My Drive/CS598DLHProject/data/preprocessed_3004/dataTrainValTestSet1.npz
# x_train
# x_val
# x_test
# reg_y_train
# reg_y_val
# reg_y_test
# rol_y_train
# rol_y_val
# rol_y_test
# done
# x_train:  (79924, 2199)
# x_val:  (12788, 2199)
# y_train:  (79924, 4103)
# y_val:  (12788, 4103)
# 35

# %%
gc.collect()
# Out:
# 88

# %%
# !pip3 install pickle5
# import pickle5 as pkl5

with open(DATA_PATH + 'row_index_dictionary.p', 'rb') as f:
    word_index = pkl.load(f)
    print("Got word index")
# Out:
# Got word index

# %%
embedding_matrix = np.load(DATA_PATH + 'embedding_matrix.p', allow_pickle=True)

# %%
from tensorflow.keras.callbacks import Callback
# from sklearn.metrics import precision_score, recall_score, f1_score
import numpy as np
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Embedding, Dense, GlobalAveragePooling1D, Conv1D, ReLU
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import backend as k

# %%
class GarbageCollectorCallback(Callback):
    def on_epoch_end(self, epoch, logs=None):
        gc.collect()
        k.clear_session()

# %%
# import keras

# model = Sequential()
# model.add(Embedding(len(word_index) , embedding_matrix.shape[1],
#                     weights=[embedding_matrix], input_length=x_train.shape[1],
#                     trainable=True))
# model.add(GlobalAveragePooling1D())
# model.add(Dense(y_train.shape[1], activation='sigmoid'))

# model.compile(loss='binary_crossentropy', optimizer='adam', metrics=[keras.metrics.Precision(), keras.metrics.Recall()])

# filename = "abc"
# # metrics = Metrics([x_val, y_val], '{}.log'.format(filename))
# early_stopping = EarlyStopping(min_delta=.0001, patience=2)
# model.fit(x_train, y_train,
#           batch_size=32, epochs=25,
#           validation_data=[x_val, y_val],
#           callbacks=[early_stopping])
# Out:
# Epoch 1/25
# 7993/7993 [==============================] - 137s 17ms/step - loss: 0.0189 - precision: 0.4423 - recall: 0.0414 - val_loss: 0.0180 - val_precision: 0.6323 - val_recall: 0.0416
# Epoch 2/25
# 7993/7993 [==============================] - 236s 29ms/step - loss: 0.0179 - precision: 0.6305 - recall: 0.0459 - val_loss: 0.0177 - val_precision: 0.6365 - val_recall: 0.0500
# Epoch 3/25
# 7993/7993 [==============================] - 789s 99ms/step - loss: 0.0176 - precision: 0.6380 - recall: 0.0542 - val_loss: 0.0174 - val_precision: 0.6493 - val_recall: 0.0562
# Epoch 4/25
# 7993/7993 [==============================] - 989s 124ms/step - loss: 0.0173 - precision: 0.6478 - recall: 0.0641 - val_loss: 0.0171 - val_precision: 0.6530 - val_recall: 0.0705
# Epoch 5/25
# 7993/7993 [==============================] - 128s 16ms/step - loss: 0.0170 - precision: 0.6550 - recall: 0.0734 - val_loss: 0.0169 - val_precision: 0.6623 - val_recall: 0.0764
# Epoch 6/25
# 7993/7993 [==============================] - 128s 16ms/step - loss: 0.0168 - precision: 0.6614 - recall: 0.0811 - val_loss: 0.0167 - val_precision: 0.6657 - val_recall: 0.0833
# Epoch 7/25
# 7993/7993 [==============================] - 127s 16ms/step - loss: 0.0166 - precision: 0.6679 - recall: 0.0876 - val_loss: 0.0165 - val_precision: 0.6806 - val_recall: 0.0853
# Epoch 8/25
# 7993/7993 [==============================] - 128s 16ms/step - loss: 0.0164 - precision: 0.6738 - recall: 0.0934 - val_loss: 0.0164 - val_precision: 0.6692 - val_recall: 0.0978
# Epoch 9/25
# 7993/7993 [==============================] - 127s 16ms/step - loss: 0.0163 - precision: 0.6789 - recall: 0.0985 - val_loss: 0.0162 - val_precision: 0.6775 - val_recall: 0.0993
# Epoch 10/25
# 7993/7993 [==============================] - 128s 16ms/step - loss: 0.0161 - precision: 0.6839 - recall: 0.1033 - val_loss: 0.0161 - val_precision: 0.6893 - val_recall: 0.0998
# Epoch 11/25
# 7993/7993 [==============================] - 214s 27ms/step - loss: 0.0160 - precision: 0.6886 - recall: 0.1080 - val_loss: 0.0160 - val_precision: 0.6553 - val_recall: 0.1143
# Epoch 12/25
# 7993/7993 [==============================] - 440s 55ms/step - loss: 0.0159 - precision: 0.6929 - recall: 0.1124 - val_loss: 0.0159 - val_precision: 0.6882 - val_recall: 0.1126
# Epoch 13/25
# 7993/7993 [==============================] - 756s 95ms/step - loss: 0.0158 - precision: 0.6973 - recall: 0.1167 - val_loss: 0.0158 - val_precision: 0.6986 - val_recall: 0.1118
# Epoch 14/25
# 7993/7993 [==============================] - 1011s 127ms/step - loss: 0.0157 - precision: 0.7021 - recall: 0.1210 - val_loss: 0.0157 - val_precision: 0.6914 - val_recall: 0.1226
# Epoch 15/25
# 7993/7993 [==============================] - 3695s 462ms/step - loss: 0.0156 - precision: 0.7061 - recall: 0.1250 - val_loss: 0.0156 - val_precision: 0.6989 - val_recall: 0.1249
# Epoch 16/25
# 7993/7993 [==============================] - 128s 16ms/step - loss: 0.0155 - precision: 0.7104 - recall: 0.1290 - val_loss: 0.0156 - val_precision: 0.7033 - val_recall: 0.1262
# Epoch 17/25
# 7993/7993 [==============================] - 128s 16ms/step - loss: 0.0154 - precision: 0.7139 - recall: 0.1327 - val_loss: 0.0155 - val_precision: 0.6867 - val_recall: 0.1375
# Epoch 18/25
# 7993/7993 [==============================] - 128s 16ms/step - loss: 0.0153 - precision: 0.7177 - recall: 0.1364 - val_loss: 0.0154 - val_precision: 0.7067 - val_recall: 0.1345
# Epoch 19/25
# 7993/7993 [==============================] - 127s 16ms/step - loss: 0.0152 - precision: 0.7209 - recall: 0.1398 - val_loss: 0.0153 - val_precision: 0.7049 - val_recall: 0.1390
# Epoch 20/25
# 7993/7993 [==============================] - 127s 16ms/step - loss: 0.0151 - precision: 0.7245 - recall: 0.1432 - val_loss: 0.0153 - val_precision: 0.7149 - val_recall: 0.1386
# Epoch 21/25
# 7993/7993 [==============================] - 128s 16ms/step - loss: 0.0150 - precision: 0.7273 - recall: 0.1465 - val_loss: 0.0152 - val_precision: 0.7087 - val_recall: 0.1461
# Epoch 22/25
# 7993/7993 [==============================] - 127s 16ms/step - loss: 0.0150 - precision: 0.7301 - recall: 0.1498 - val_loss: 0.0151 - val_precision: 0.7166 - val_recall: 0.1475
# Epoch 23/25
# 7993/7993 [==============================] - 128s 16ms/step - loss: 0.0149 - precision: 0.7333 - recall: 0.1528 - val_loss: 0.0151 - val_precision: 0.7061 - val_recall: 0.1571
# Epoch 24/25
# 7993/7993 [==============================] - 126s 16ms/step - loss: 0.0148 - precision: 0.7359 - recall: 0.1558 - val_loss: 0.0150 - val_precision: 0.7261 - val_recall: 0.1494

# %%
# model.save(DATA_PATH + 'BOTModelRegular.h5')

# %%
# Set 1 completed

# from keras import metrics

# model = Sequential()
# model.add(Embedding(len(word_index) , embedding_matrix.shape[1],
#                     weights=[embedding_matrix], input_length=x_train.shape[1],
#                     trainable=True))
# model.add(Conv1D(250, 3, activation='relu'))
# # model.add(ReLU())
# model.add(GlobalAveragePooling1D())
# model.add(Dense(y_train.shape[1], activation='sigmoid'))

# model.compile(loss='binary_crossentropy', optimizer='adam', metrics=[metrics.Precision(), metrics.Recall()], run_eagerly=True)


# # metrics = Metrics([x_val, y_val], '{}.log'.format(filename))
# early_stopping = EarlyStopping(min_delta=.0001, patience=2)
# garbage_collection = GarbageCollectorCallback()
# model.fit(x_train, y_train,
#           batch_size=32, epochs=25,
#           validation_data=[x_val, y_val],
#           callbacks=[early_stopping, garbage_collection])
# Out:
# Epoch 1/25
# 2498/2498 [==============================] - 159s 59ms/step - loss: 0.0197 - precision: 0.2445 - recall: 0.0444 - val_loss: 0.0182 - val_precision: 0.5991 - val_recall: 0.0519
# Epoch 2/25
# 2498/2498 [==============================] - 140s 56ms/step - loss: 0.0180 - precision: 0.6164 - recall: 0.0521 - val_loss: 0.0177 - val_precision: 0.6407 - val_recall: 0.0564
# Epoch 3/25
# 2498/2498 [==============================] - 140s 56ms/step - loss: 0.0176 - precision: 0.6308 - recall: 0.0657 - val_loss: 0.0174 - val_precision: 0.6257 - val_recall: 0.0765
# Epoch 4/25
# 2498/2498 [==============================] - 140s 56ms/step - loss: 0.0172 - precision: 0.6360 - recall: 0.0771 - val_loss: 0.0171 - val_precision: 0.6434 - val_recall: 0.0789
# Epoch 5/25
# 2498/2498 [==============================] - 139s 56ms/step - loss: 0.0169 - precision: 0.6477 - recall: 0.0857 - val_loss: 0.0168 - val_precision: 0.6443 - val_recall: 0.0928
# Epoch 6/25
# 2498/2498 [==============================] - 139s 56ms/step - loss: 0.0166 - precision: 0.6578 - recall: 0.0942 - val_loss: 0.0165 - val_precision: 0.6612 - val_recall: 0.0944
# Epoch 7/25
# 2498/2498 [==============================] - 139s 55ms/step - loss: 0.0164 - precision: 0.6649 - recall: 0.1017 - val_loss: 0.0163 - val_precision: 0.6601 - val_recall: 0.1043
# Epoch 8/25
# 2498/2498 [==============================] - 139s 56ms/step - loss: 0.0161 - precision: 0.6715 - recall: 0.1085 - val_loss: 0.0162 - val_precision: 0.6599 - val_recall: 0.1109
# Epoch 9/25
# 2498/2498 [==============================] - 138s 55ms/step - loss: 0.0159 - precision: 0.6785 - recall: 0.1149 - val_loss: 0.0160 - val_precision: 0.6678 - val_recall: 0.1129
# Epoch 10/25
# 2498/2498 [==============================] - 138s 55ms/step - loss: 0.0157 - precision: 0.6840 - recall: 0.1214 - val_loss: 0.0159 - val_precision: 0.6700 - val_recall: 0.1197
# Epoch 11/25
# 2498/2498 [==============================] - 139s 55ms/step - loss: 0.0156 - precision: 0.6896 - recall: 0.1275 - val_loss: 0.0158 - val_precision: 0.6667 - val_recall: 0.1264
# Epoch 12/25
# 2498/2498 [==============================] - 139s 55ms/step - loss: 0.0154 - precision: 0.6959 - recall: 0.1333 - val_loss: 0.0156 - val_precision: 0.6736 - val_recall: 0.1339
# Epoch 13/25
# 2498/2498 [==============================] - 139s 55ms/step - loss: 0.0152 - precision: 0.7023 - recall: 0.1395 - val_loss: 0.0155 - val_precision: 0.6753 - val_recall: 0.1395
# Epoch 14/25
# 2498/2498 [==============================] - 138s 55ms/step - loss: 0.0151 - precision: 0.7073 - recall: 0.1453 - val_loss: 0.0154 - val_precision: 0.6741 - val_recall: 0.1481
# Epoch 15/25
# 2498/2498 [==============================] - 138s 55ms/step - loss: 0.0149 - precision: 0.7116 - recall: 0.1511 - val_loss: 0.0153 - val_precision: 0.6868 - val_recall: 0.1460
# Epoch 16/25
# 2498/2498 [==============================] - 138s 55ms/step - loss: 0.0148 - precision: 0.7162 - recall: 0.1564 - val_loss: 0.0152 - val_precision: 0.6867 - val_recall: 0.1515
# Epoch 17/25
# 2498/2498 [==============================] - 138s 55ms/step - loss: 0.0147 - precision: 0.7213 - recall: 0.1617 - val_loss: 0.0151 - val_precision: 0.6923 - val_recall: 0.1501
# Epoch 18/25
# 2498/2498 [==============================] - 138s 55ms/step - loss: 0.0145 - precision: 0.7257 - recall: 0.1672 - val_loss: 0.0150 - val_precision: 0.6875 - val_recall: 0.1607
# Epoch 19/25
# 2498/2498 [==============================] - 138s 55ms/step - loss: 0.0144 - precision: 0.7303 - recall: 0.1723 - val_loss: 0.0149 - val_precision: 0.6942 - val_recall: 0.1638
# Epoch 20/25
# 2498/2498 [==============================] - 138s 55ms/step - loss: 0.0143 - precision: 0.7347 - recall: 0.1774 - val_loss: 0.0149 - val_precision: 0.6890 - val_recall: 0.1732
# Epoch 21/25
# 2498/2498 [==============================] - 137s 55ms/step - loss: 0.0142 - precision: 0.7388 - recall: 0.1823 - val_loss: 0.0148 - val_precision: 0.6911 - val_recall: 0.1768
# Epoch 22/25
# 2498/2498 [==============================] - 138s 55ms/step - loss: 0.0141 - precision: 0.7427 - recall: 0.1870 - val_loss: 0.0147 - val_precision: 0.6931 - val_recall: 0.1792
# Epoch 23/25
# 2498/2498 [==============================] - 138s 55ms/step - loss: 0.0140 - precision: 0.7461 - recall: 0.1915 - val_loss: 0.0147 - val_precision: 0.6989 - val_recall: 0.1798
# Epoch 24/25
# 2498/2498 [==============================] - 138s 55ms/step - loss: 0.0139 - precision: 0.7492 - recall: 0.1962 - val_loss: 0.0147 - val_precision: 0.7063 - val_recall: 0.1809

# %%
# model.save(DATA_PATH + 'CNNBaselineRegularSet1.h5')

# %% [markdown]
# ###Set2

# %%
# import gzip
# import pickle as pkl
# import gc

# import numpy as np

# DATA_DIR = mypath + "/data/"

# DATA_PATH = DATA_DIR + "preprocessed_3004/"
# DATA_NPZ_FILE = f'{DATA_PATH}dataTrainValTestSet2.npz'

# print ('reading from saved file: ', DATA_NPZ_FILE)
# data = np.load(DATA_NPZ_FILE)
# lst = data.files
# for item in lst:
#     print(item)

# print("done")
# x_train_load = data['x_train']
# x_val_load = data['x_val']
# # x_test = data['x_test']

# x_train = x_train_load
# x_val = x_val_load
# # x_test = x_test

# del x_train_load
# del x_val_load

# print('x_train: ' , x_train.shape)
# print('x_val: ', x_val.shape)
# # print('x_test: ', x_test.shape)

# # rol_y_train = data['rol_y_train']
# # rol_y_val = data['rol_y_val']
# # rol_y_test = data['rol_y_test']

# # print('rol_y_train: ', rol_y_train.shape)
# # print('rol_y_val: ', rol_y_val.shape)
# # print('rol_y_test: ', rol_y_test.shape)

# # y_train = rol_y_train
# # y_val = rol_y_val
# # y_test = rol_y_test


# reg_y_train = data['reg_y_train']
# reg_y_val = data['reg_y_val']
# # reg_y_test = data['reg_y_test']


# y_train = reg_y_train
# y_val = reg_y_val
# # y_test = reg_y_test

# print('y_train: ', y_train.shape)
# print('y_val: ', y_val.shape)
# # print('reg_y_test: ', reg_y_test.shape)

# del data
# del lst
# del reg_y_train
# del reg_y_val
# # del reg_y_test


# with open(DATA_PATH + 'row_index_dictionary.p', 'rb') as f:
#     word_index = pkl.load(f)
#     print("Got word index")

# embedding_matrix = np.load(DATA_PATH + 'embedding_matrix.p', allow_pickle=True)

# gc.collect()
# Out:
# reading from saved file:  drive/My Drive/CS598DLHProject/data/preprocessed_3004/dataTrainValTestSet2.npz
# x_train
# x_val
# x_test
# reg_y_train
# reg_y_val
# reg_y_test
# rol_y_train
# rol_y_val
# rol_y_test
# done
# x_train:  (79925, 2199)
# x_val:  (12788, 2199)
# y_train:  (79925, 4103)
# y_val:  (12788, 4103)
# Got word index
# 43

# %%
# from tensorflow.keras.callbacks import Callback
# # from sklearn.metrics import precision_score, recall_score, f1_score
# import numpy as np
# from tensorflow.keras.models import Sequential, load_model
# from tensorflow.keras.layers import Embedding, Dense, GlobalAveragePooling1D, Conv1D, ReLU
# from tensorflow.keras.callbacks import EarlyStopping
# from tensorflow.keras import backend as k

# %%
# class GarbageCollectorCallback(Callback):
#     def on_epoch_end(self, epoch, logs=None):
#         gc.collect()
#         k.clear_session()

# %%
# model = load_model(DATA_PATH + 'CNNBaselineRegularSet1.h5')

# early_stopping = EarlyStopping(min_delta=.0001, patience=2)
# garbage_collection = GarbageCollectorCallback()
# model.fit(x_train, y_train,
#           batch_size=32, epochs=25,
#           validation_data=[x_val, y_val],
#           callbacks=[early_stopping, garbage_collection])
# Out:
# Epoch 1/25
#    5/2498 [..............................] - ETA: 1:25 - loss: 0.0146 - precision: 0.6979 - recall: 0.1781WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0122s vs `on_train_batch_end` time: 0.0178s). Check your callbacks.
# 2498/2498 [==============================] - 90s 33ms/step - loss: 0.0146 - precision: 0.7223 - recall: 0.1765 - val_loss: 0.0145 - val_precision: 0.7322 - val_recall: 0.1732
# Epoch 2/25
# 2498/2498 [==============================] - 82s 33ms/step - loss: 0.0144 - precision: 0.7359 - recall: 0.1810 - val_loss: 0.0144 - val_precision: 0.7240 - val_recall: 0.1810
# Epoch 3/25
# 2498/2498 [==============================] - 82s 33ms/step - loss: 0.0142 - precision: 0.7426 - recall: 0.1866 - val_loss: 0.0144 - val_precision: 0.7244 - val_recall: 0.1840
# Epoch 4/25
# 2498/2498 [==============================] - 83s 33ms/step - loss: 0.0141 - precision: 0.7473 - recall: 0.1918 - val_loss: 0.0143 - val_precision: 0.7217 - val_recall: 0.1904
# Epoch 5/25
# 2498/2498 [==============================] - 82s 33ms/step - loss: 0.0140 - precision: 0.7519 - recall: 0.1969 - val_loss: 0.0142 - val_precision: 0.7363 - val_recall: 0.1888
# Epoch 6/25
# 2498/2498 [==============================] - 83s 33ms/step - loss: 0.0138 - precision: 0.7565 - recall: 0.2023 - val_loss: 0.0142 - val_precision: 0.7311 - val_recall: 0.1954
# Epoch 7/25
# 2498/2498 [==============================] - 82s 33ms/step - loss: 0.0137 - precision: 0.7596 - recall: 0.2067 - val_loss: 0.0141 - val_precision: 0.7284 - val_recall: 0.1987

# %%
# model.save(DATA_PATH + 'CNNBaselineRegularSet2.h5')

# %% [markdown]
# ###Set3

# %%
# import gzip
# import pickle as pkl
# import gc

# import numpy as np

# DATA_DIR = mypath + "/data/"

# DATA_PATH = DATA_DIR + "preprocessed_3004/"
# DATA_NPZ_FILE = f'{DATA_PATH}dataTrainValTestSet3.npz'

# print ('reading from saved file: ', DATA_NPZ_FILE)
# data = np.load(DATA_NPZ_FILE)
# lst = data.files
# for item in lst:
#     print(item)

# print("done")
# x_train_load = data['x_train']
# x_val_load = data['x_val']
# # x_test = data['x_test']

# x_train = x_train_load
# x_val = x_val_load
# # x_test = x_test

# del x_train_load
# del x_val_load

# print('x_train: ' , x_train.shape)
# print('x_val: ', x_val.shape)
# # print('x_test: ', x_test.shape)

# # rol_y_train = data['rol_y_train']
# # rol_y_val = data['rol_y_val']
# # rol_y_test = data['rol_y_test']

# # print('rol_y_train: ', rol_y_train.shape)
# # print('rol_y_val: ', rol_y_val.shape)
# # print('rol_y_test: ', rol_y_test.shape)

# # y_train = rol_y_train
# # y_val = rol_y_val
# # y_test = rol_y_test


# reg_y_train = data['reg_y_train']
# reg_y_val = data['reg_y_val']
# # reg_y_test = data['reg_y_test']


# y_train = reg_y_train
# y_val = reg_y_val
# # y_test = reg_y_test

# print('y_train: ', y_train.shape)
# print('y_val: ', y_val.shape)
# # print('reg_y_test: ', reg_y_test.shape)

# del data
# del lst
# del reg_y_train
# del reg_y_val
# # del reg_y_test


# with open(DATA_PATH + 'row_index_dictionary.p', 'rb') as f:
#     word_index = pkl.load(f)
#     print("Got word index")

# embedding_matrix = np.load(DATA_PATH + 'embedding_matrix.p', allow_pickle=True)

# gc.collect()
# Out:
# reading from saved file:  drive/My Drive/CS598DLHProject/data/preprocessed_3004/dataTrainValTestSet3.npz
# x_train
# x_val
# x_test
# reg_y_train
# reg_y_val
# reg_y_test
# rol_y_train
# rol_y_val
# rol_y_test
# done
# x_train:  (79924, 2199)
# x_val:  (12788, 2199)
# y_train:  (79924, 4103)
# y_val:  (12788, 4103)
# Got word index
# 35

# %%
# from tensorflow.keras.callbacks import Callback
# # from sklearn.metrics import precision_score, recall_score, f1_score
# import numpy as np
# from tensorflow.keras.models import Sequential, load_model
# from tensorflow.keras.layers import Embedding, Dense, GlobalAveragePooling1D, Conv1D, ReLU
# from tensorflow.keras.callbacks import EarlyStopping
# from tensorflow.keras import backend as k

# class GarbageCollectorCallback(Callback):
#     def on_epoch_end(self, epoch, logs=None):
#         gc.collect()
#         k.clear_session()

# %%
# model = load_model(DATA_PATH + 'CNNBaselineRegularSet2.h5')

# early_stopping = EarlyStopping(min_delta=.0001, patience=3)
# garbage_collection = GarbageCollectorCallback()
# model.fit(x_train, y_train,
#           batch_size=32, epochs=25,
#           validation_data=[x_val, y_val],
#           callbacks=[early_stopping, garbage_collection])
# Out:
# Epoch 1/25
#    6/2498 [..............................] - ETA: 1:29 - loss: 0.0142 - precision: 0.7222 - recall: 0.2007WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0109s vs `on_train_batch_end` time: 0.0208s). Check your callbacks.
# 2498/2498 [==============================] - 85s 33ms/step - loss: 0.0141 - precision: 0.7425 - recall: 0.1963 - val_loss: 0.0142 - val_precision: 0.7489 - val_recall: 0.1950
# Epoch 2/25
# 2498/2498 [==============================] - 81s 32ms/step - loss: 0.0139 - precision: 0.7534 - recall: 0.2019 - val_loss: 0.0141 - val_precision: 0.7552 - val_recall: 0.1940
# Epoch 3/25
# 2498/2498 [==============================] - 82s 33ms/step - loss: 0.0138 - precision: 0.7593 - recall: 0.2072 - val_loss: 0.0140 - val_precision: 0.7461 - val_recall: 0.2051
# Epoch 4/25
# 2498/2498 [==============================] - 81s 33ms/step - loss: 0.0137 - precision: 0.7640 - recall: 0.2122 - val_loss: 0.0140 - val_precision: 0.7526 - val_recall: 0.2006
# Epoch 5/25
# 2498/2498 [==============================] - 81s 33ms/step - loss: 0.0135 - precision: 0.7670 - recall: 0.2167 - val_loss: 0.0140 - val_precision: 0.7435 - val_recall: 0.2091
# Epoch 6/25
# 2498/2498 [==============================] - 81s 33ms/step - loss: 0.0134 - precision: 0.7705 - recall: 0.2215 - val_loss: 0.0139 - val_precision: 0.7404 - val_recall: 0.2136
# Epoch 7/25
# 2498/2498 [==============================] - 81s 33ms/step - loss: 0.0133 - precision: 0.7731 - recall: 0.2258 - val_loss: 0.0139 - val_precision: 0.7485 - val_recall: 0.2117
# Epoch 8/25
# 2498/2498 [==============================] - 81s 33ms/step - loss: 0.0132 - precision: 0.7764 - recall: 0.2300 - val_loss: 0.0139 - val_precision: 0.7422 - val_recall: 0.2184
# Epoch 9/25
# 2498/2498 [==============================] - 82s 33ms/step - loss: 0.0131 - precision: 0.7793 - recall: 0.2345 - val_loss: 0.0139 - val_precision: 0.7389 - val_recall: 0.2243

# %%
# model.save(DATA_PATH + 'CNNBaselineRegularSet3.h5')

# %% [markdown]
# ### Set4

# %%
import gzip
import pickle as pkl
import gc

import numpy as np

DATA_DIR = mypath + "/data/"

DATA_PATH = DATA_DIR + "preprocessed_3004/"
DATA_NPZ_FILE = f'{DATA_PATH}dataTrainValTestSet4.npz'

print ('reading from saved file: ', DATA_NPZ_FILE)
data = np.load(DATA_NPZ_FILE)
lst = data.files
for item in lst:
    print(item)

print("done")
x_train_load = data['x_train']
x_val_load = data['x_val']
# x_test = data['x_test']

x_train = x_train_load
x_val = x_val_load
# x_test = x_test

del x_train_load
del x_val_load

print('x_train: ' , x_train.shape)
print('x_val: ', x_val.shape)
# print('x_test: ', x_test.shape)

# rol_y_train = data['rol_y_train']
# rol_y_val = data['rol_y_val']
# rol_y_test = data['rol_y_test']

# print('rol_y_train: ', rol_y_train.shape)
# print('rol_y_val: ', rol_y_val.shape)
# print('rol_y_test: ', rol_y_test.shape)

# y_train = rol_y_train
# y_val = rol_y_val
# y_test = rol_y_test


reg_y_train = data['reg_y_train']
reg_y_val = data['reg_y_val']
# reg_y_test = data['reg_y_test']


y_train = reg_y_train
y_val = reg_y_val
# y_test = reg_y_test

print('y_train: ', y_train.shape)
print('y_val: ', y_val.shape)
# print('reg_y_test: ', reg_y_test.shape)

del data
del lst
del reg_y_train
del reg_y_val
# del reg_y_test


with open(DATA_PATH + 'row_index_dictionary.p', 'rb') as f:
    word_index = pkl.load(f)
    print("Got word index")

embedding_matrix = np.load(DATA_PATH + 'embedding_matrix.p', allow_pickle=True)

gc.collect()
# Out:
# reading from saved file:  drive/My Drive/CS598DLHProject/data/preprocessed_3004/dataTrainValTestSet4.npz
# x_train
# x_val
# x_test
# reg_y_train
# reg_y_val
# reg_y_test
# rol_y_train
# rol_y_val
# rol_y_test
# done
# x_train:  (15985, 2199)
# x_val:  (12788, 2199)
# y_train:  (15985, 4103)
# y_val:  (12788, 4103)
# Got word index
# 35

# %%
from tensorflow.keras.callbacks import Callback
# from sklearn.metrics import precision_score, recall_score, f1_score
import numpy as np
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Embedding, Dense, GlobalAveragePooling1D, Conv1D, ReLU
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import backend as k

class GarbageCollectorCallback(Callback):
    def on_epoch_end(self, epoch, logs=None):
        gc.collect()
        k.clear_session()

# %%
model = load_model(DATA_PATH + 'CNNBaselineRegularSet3.h5')

early_stopping = EarlyStopping(min_delta=.0001, patience=2)
garbage_collection = GarbageCollectorCallback()
model.fit(x_train, y_train,
          batch_size=32, epochs=25,
          validation_data=[x_val, y_val],
          callbacks=[early_stopping, garbage_collection])
# Out:
# Epoch 1/25
# 500/500 [==============================] - 21s 39ms/step - loss: 0.0137 - precision: 0.7493 - recall: 0.2216 - val_loss: 0.0137 - val_precision: 0.7582 - val_recall: 0.2221
# Epoch 2/25
# 500/500 [==============================] - 19s 38ms/step - loss: 0.0135 - precision: 0.7655 - recall: 0.2249 - val_loss: 0.0137 - val_precision: 0.7499 - val_recall: 0.2263
# Epoch 3/25
# 500/500 [==============================] - 19s 38ms/step - loss: 0.0133 - precision: 0.7730 - recall: 0.2293 - val_loss: 0.0137 - val_precision: 0.7482 - val_recall: 0.2248

# %%
model.save(DATA_PATH + 'CNNBaselineRegularSet4.h5')

# %% [markdown]
# ### Set5

# %%
import gzip
import pickle as pkl
import gc

import numpy as np

DATA_DIR = mypath + "/data/"

DATA_PATH = DATA_DIR + "preprocessed_3004/"
DATA_NPZ_FILE = f'{DATA_PATH}dataTrainValTestSet5.npz'

print ('reading from saved file: ', DATA_NPZ_FILE)
data = np.load(DATA_NPZ_FILE)
lst = data.files
for item in lst:
    print(item)

print("done")
x_train_load = data['x_train']
x_val_load = data['x_val']
# x_test = data['x_test']

x_train = x_train_load
x_val = x_val_load
# x_test = x_test

del x_train_load
del x_val_load

print('x_train: ' , x_train.shape)
print('x_val: ', x_val.shape)
# print('x_test: ', x_test.shape)

# rol_y_train = data['rol_y_train']
# rol_y_val = data['rol_y_val']
# rol_y_test = data['rol_y_test']

# print('rol_y_train: ', rol_y_train.shape)
# print('rol_y_val: ', rol_y_val.shape)
# print('rol_y_test: ', rol_y_test.shape)

# y_train = rol_y_train
# y_val = rol_y_val
# y_test = rol_y_test


reg_y_train = data['reg_y_train']
reg_y_val = data['reg_y_val']
# reg_y_test = data['reg_y_test']


y_train = reg_y_train
y_val = reg_y_val
# y_test = reg_y_test

print('y_train: ', y_train.shape)
print('y_val: ', y_val.shape)
# print('reg_y_test: ', reg_y_test.shape)

del data
del lst
del reg_y_train
del reg_y_val
# del reg_y_test


with open(DATA_PATH + 'row_index_dictionary.p', 'rb') as f:
    word_index = pkl.load(f)
    print("Got word index")

embedding_matrix = np.load(DATA_PATH + 'embedding_matrix.p', allow_pickle=True)

gc.collect()
# Out:
# reading from saved file:  drive/My Drive/CS598DLHProject/data/preprocessed_3004/dataTrainValTestSet5.npz
# x_train
# x_val
# x_test
# reg_y_train
# reg_y_val
# reg_y_test
# rol_y_train
# rol_y_val
# rol_y_test
# done
# x_train:  (0, 2199)
# x_val:  (12788, 2199)
# y_train:  (0, 4103)
# y_val:  (12788, 4103)
# Got word index
# 43

# %%
from tensorflow.keras.callbacks import Callback
# from sklearn.metrics import precision_score, recall_score, f1_score
import numpy as np
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Embedding, Dense, GlobalAveragePooling1D, Conv1D, ReLU
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import backend as k

class GarbageCollectorCallback(Callback):
    def on_epoch_end(self, epoch, logs=None):
        gc.collect()
        k.clear_session()

# %%
model = load_model(DATA_PATH + 'CNNBaselineRegularSet4.h5')

early_stopping = EarlyStopping(min_delta=.0001, patience=2)
garbage_collection = GarbageCollectorCallback()
model.fit(x_train, y_train,
          batch_size=32, epochs=25,
          validation_data=[x_val, y_val],
          callbacks=[early_stopping, garbage_collection])

# %%
model.save(DATA_PATH + 'CNNBaselineRegularSet5.h5')

# %% [markdown]
# # CNN 3 layer

# %% [markdown]
# ### Set1

# %%
import gzip
import pickle as pkl
import gc

import numpy as np

DATA_DIR = mypath + "/data/"

DATA_PATH = DATA_DIR + "preprocessed_3004/"
DATA_NPZ_FILE = f'{DATA_PATH}dataTrainValTestSet1.npz'

print ('reading from saved file: ', DATA_NPZ_FILE)
data = np.load(DATA_NPZ_FILE)
lst = data.files
for item in lst:
    print(item)

print("done")
x_train_load = data['x_train']
x_val_load = data['x_val']
# x_test = data['x_test']

x_train = x_train_load
x_val = x_val_load
# x_test = x_test

del x_train_load
del x_val_load

print('x_train: ' , x_train.shape)
print('x_val: ', x_val.shape)
# print('x_test: ', x_test.shape)

# rol_y_train = data['rol_y_train']
# rol_y_val = data['rol_y_val']
# rol_y_test = data['rol_y_test']

# print('rol_y_train: ', rol_y_train.shape)
# print('rol_y_val: ', rol_y_val.shape)
# print('rol_y_test: ', rol_y_test.shape)

# y_train = rol_y_train
# y_val = rol_y_val
# y_test = rol_y_test


reg_y_train = data['reg_y_train']
reg_y_val = data['reg_y_val']
# reg_y_test = data['reg_y_test']


y_train = reg_y_train
y_val = reg_y_val
# y_test = reg_y_test

print('y_train: ', y_train.shape)
print('y_val: ', y_val.shape)
# print('reg_y_test: ', reg_y_test.shape)

del data
del lst
del reg_y_train
del reg_y_val
# del reg_y_test


with open(DATA_PATH + 'row_index_dictionary.p', 'rb') as f:
    word_index = pkl.load(f)
    print("Got word index")

embedding_matrix = np.load(DATA_PATH + 'embedding_matrix.p', allow_pickle=True)

gc.collect()
# Out:
# reading from saved file:  drive/My Drive/CS598DLHProject/data/preprocessed_3004/dataTrainValTestSet1.npz
# x_train
# x_val
# x_test
# reg_y_train
# reg_y_val
# reg_y_test
# rol_y_train
# rol_y_val
# rol_y_test
# done
# x_train:  (79924, 2199)
# x_val:  (12788, 2199)
# y_train:  (79924, 4103)
# y_val:  (12788, 4103)
# Got word index
# 43

# %%
from tensorflow.keras.callbacks import Callback
# from sklearn.metrics import precision_score, recall_score, f1_score
import numpy as np
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Embedding, Dense, GlobalAveragePooling1D, Conv1D, ReLU
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import backend as k
import keras
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Embedding, Dense, Conv1D, GlobalMaxPooling1D, concatenate

class GarbageCollectorCallback(Callback):
    def on_epoch_end(self, epoch, logs=None):
        gc.collect()
        k.clear_session()

# %%
# import keras
# from tensorflow.keras.callbacks import EarlyStopping
# from tensorflow.keras.models import Model
# from tensorflow.keras.layers import Input, Embedding, Dense, Conv1D, GlobalMaxPooling1D, concatenate

embedding_input = Input(shape=(x_train.shape[1],), dtype=np.int32)
embedding_layer = Embedding(len(word_index), embedding_matrix.shape[1],
                                weights=[embedding_matrix], input_length=x_train.shape[1],
                                trainable=True)(embedding_input)
x1 = Conv1D(250, 2, activation='relu')(embedding_layer)
x1 = GlobalMaxPooling1D()(x1)
x2 = Conv1D(250, 3, activation='relu')(embedding_layer)
x2 = GlobalMaxPooling1D()(x2)
x3 = Conv1D(250, 4, activation='relu')(embedding_layer)
x3 = GlobalMaxPooling1D()(x3)
x = concatenate([x1, x2, x3])
output = Dense(y_train.shape[1], activation='sigmoid')(x)

model = Model(inputs=[embedding_input], outputs=[output])

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=[keras.metrics.Precision(), keras.metrics.Recall()])


# metrics = Metrics([x_val, y_val], '{}.log'.format(filename))
early_stopping = EarlyStopping(min_delta=.0001, patience=2)
model.fit(x_train, y_train,
          batch_size=32, epochs=25,
          validation_data=[x_val, y_val],
          callbacks=[early_stopping])
# Out:
# Epoch 1/25
# 2498/2498 [==============================] - 203s 80ms/step - loss: 0.0191 - precision: 0.4627 - recall: 0.1092 - val_loss: 0.0160 - val_precision: 0.6763 - val_recall: 0.1504
# Epoch 2/25
# 2498/2498 [==============================] - 199s 80ms/step - loss: 0.0148 - precision: 0.7100 - recall: 0.1934 - val_loss: 0.0141 - val_precision: 0.7493 - val_recall: 0.2180
# Epoch 3/25
# 2498/2498 [==============================] - 198s 79ms/step - loss: 0.0133 - precision: 0.7488 - recall: 0.2577 - val_loss: 0.0134 - val_precision: 0.7467 - val_recall: 0.2610
# Epoch 4/25
# 2498/2498 [==============================] - 199s 80ms/step - loss: 0.0124 - precision: 0.7679 - recall: 0.3000 - val_loss: 0.0132 - val_precision: 0.7425 - val_recall: 0.2880
# Epoch 5/25
# 2498/2498 [==============================] - 199s 79ms/step - loss: 0.0117 - precision: 0.7795 - recall: 0.3306 - val_loss: 0.0131 - val_precision: 0.7495 - val_recall: 0.2989
# Epoch 6/25
# 2498/2498 [==============================] - 199s 80ms/step - loss: 0.0112 - precision: 0.7897 - recall: 0.3550 - val_loss: 0.0133 - val_precision: 0.7459 - val_recall: 0.3050

# %%
model.save(DATA_PATH + 'CNN3LayerRegularSet1.h5')

# %% [markdown]
# ###Set2

# %%
import gzip
import pickle as pkl
import gc

import numpy as np

DATA_DIR = mypath + "/data/"

DATA_PATH = DATA_DIR + "preprocessed_3004/"
DATA_NPZ_FILE = f'{DATA_PATH}dataTrainValTestSet2.npz'

print ('reading from saved file: ', DATA_NPZ_FILE)
data = np.load(DATA_NPZ_FILE)
lst = data.files
for item in lst:
    print(item)

print("done")
x_train_load = data['x_train']
x_val_load = data['x_val']
# x_test = data['x_test']

x_train = x_train_load
x_val = x_val_load
# x_test = x_test

del x_train_load
del x_val_load

print('x_train: ' , x_train.shape)
print('x_val: ', x_val.shape)
# print('x_test: ', x_test.shape)

# rol_y_train = data['rol_y_train']
# rol_y_val = data['rol_y_val']
# rol_y_test = data['rol_y_test']

# print('rol_y_train: ', rol_y_train.shape)
# print('rol_y_val: ', rol_y_val.shape)
# print('rol_y_test: ', rol_y_test.shape)

# y_train = rol_y_train
# y_val = rol_y_val
# y_test = rol_y_test


reg_y_train = data['reg_y_train']
reg_y_val = data['reg_y_val']
# reg_y_test = data['reg_y_test']


y_train = reg_y_train
y_val = reg_y_val
# y_test = reg_y_test

print('y_train: ', y_train.shape)
print('y_val: ', y_val.shape)
# print('reg_y_test: ', reg_y_test.shape)

del data
del lst
del reg_y_train
del reg_y_val
# del reg_y_test


with open(DATA_PATH + 'row_index_dictionary.p', 'rb') as f:
    word_index = pkl.load(f)
    print("Got word index")

embedding_matrix = np.load(DATA_PATH + 'embedding_matrix.p', allow_pickle=True)

gc.collect()
# Out:
# reading from saved file:  drive/My Drive/CS598DLHProject/data/preprocessed_3004/dataTrainValTestSet2.npz
# x_train
# x_val
# x_test
# reg_y_train
# reg_y_val
# reg_y_test
# rol_y_train
# rol_y_val
# rol_y_test
# done
# x_train:  (79925, 2199)
# x_val:  (12788, 2199)
# y_train:  (79925, 4103)
# y_val:  (12788, 4103)
# Got word index
# 1443

# %%
from tensorflow.keras.callbacks import Callback
# from sklearn.metrics import precision_score, recall_score, f1_score
import numpy as np
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Embedding, Dense, GlobalAveragePooling1D, Conv1D, ReLU
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import backend as k
import keras
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Embedding, Dense, Conv1D, GlobalMaxPooling1D, concatenate

class GarbageCollectorCallback(Callback):
    def on_epoch_end(self, epoch, logs=None):
        gc.collect()
        k.clear_session()


model = load_model(DATA_PATH + 'CNN3LayerRegularSet1.h5')

early_stopping = EarlyStopping(min_delta=.0001, patience=2)
garbage_collection = GarbageCollectorCallback()
model.fit(x_train, y_train,
          batch_size=32, epochs=25,
          validation_data=[x_val, y_val],
          callbacks=[early_stopping, garbage_collection])
# Out:
# Epoch 1/25
# 2498/2498 [==============================] - 199s 80ms/step - loss: 0.0129 - precision: 0.7721 - recall: 0.2917 - val_loss: 0.0126 - val_precision: 0.7841 - val_recall: 0.2970
# Epoch 2/25
# 2498/2498 [==============================] - 198s 79ms/step - loss: 0.0119 - precision: 0.7932 - recall: 0.3274 - val_loss: 0.0126 - val_precision: 0.7792 - val_recall: 0.3069
# Epoch 3/25
# 2498/2498 [==============================] - 198s 79ms/step - loss: 0.0114 - precision: 0.8010 - recall: 0.3490 - val_loss: 0.0126 - val_precision: 0.7685 - val_recall: 0.3200

# %%
model.save(DATA_PATH + 'CNN3LayerRegularSet2.h5')

# %% [markdown]
# ### Set3

# %%
import gzip
import pickle as pkl
import gc

import numpy as np

DATA_DIR = mypath + "/data/"

DATA_PATH = DATA_DIR + "preprocessed_3004/"
DATA_NPZ_FILE = f'{DATA_PATH}dataTrainValTestSet3.npz'

print ('reading from saved file: ', DATA_NPZ_FILE)
data = np.load(DATA_NPZ_FILE)
lst = data.files
for item in lst:
    print(item)

print("done")
x_train_load = data['x_train']
x_val_load = data['x_val']
# x_test = data['x_test']

x_train = x_train_load
x_val = x_val_load
# x_test = x_test

del x_train_load
del x_val_load

print('x_train: ' , x_train.shape)
print('x_val: ', x_val.shape)
# print('x_test: ', x_test.shape)

# rol_y_train = data['rol_y_train']
# rol_y_val = data['rol_y_val']
# rol_y_test = data['rol_y_test']

# print('rol_y_train: ', rol_y_train.shape)
# print('rol_y_val: ', rol_y_val.shape)
# print('rol_y_test: ', rol_y_test.shape)

# y_train = rol_y_train
# y_val = rol_y_val
# y_test = rol_y_test


reg_y_train = data['reg_y_train']
reg_y_val = data['reg_y_val']
# reg_y_test = data['reg_y_test']


y_train = reg_y_train
y_val = reg_y_val
# y_test = reg_y_test

print('y_train: ', y_train.shape)
print('y_val: ', y_val.shape)
# print('reg_y_test: ', reg_y_test.shape)

del data
del lst
del reg_y_train
del reg_y_val
# del reg_y_test


with open(DATA_PATH + 'row_index_dictionary.p', 'rb') as f:
    word_index = pkl.load(f)
    print("Got word index")

embedding_matrix = np.load(DATA_PATH + 'embedding_matrix.p', allow_pickle=True)

gc.collect()
# Out:
# reading from saved file:  drive/My Drive/CS598DLHProject/data/preprocessed_3004/dataTrainValTestSet3.npz
# x_train
# x_val
# x_test
# reg_y_train
# reg_y_val
# reg_y_test
# rol_y_train
# rol_y_val
# rol_y_test
# done
# x_train:  (79924, 2199)
# x_val:  (12788, 2199)
# y_train:  (79924, 4103)
# y_val:  (12788, 4103)
# Got word index
# 43

# %%
from tensorflow.keras.callbacks import Callback
# from sklearn.metrics import precision_score, recall_score, f1_score
import numpy as np
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Embedding, Dense, GlobalAveragePooling1D, Conv1D, ReLU
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import backend as k
import keras
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Embedding, Dense, Conv1D, GlobalMaxPooling1D, concatenate

class GarbageCollectorCallback(Callback):
    def on_epoch_end(self, epoch, logs=None):
        gc.collect()
        k.clear_session()


model = load_model(DATA_PATH + 'CNN3LayerRegularSet2.h5')

early_stopping = EarlyStopping(min_delta=.0001, patience=2)
garbage_collection = GarbageCollectorCallback()
model.fit(x_train, y_train,
          batch_size=32, epochs=25,
          validation_data=[x_val, y_val],
          callbacks=[early_stopping, garbage_collection])
# Out:
# Epoch 1/25
# 2498/2498 [==============================] - 319s 123ms/step - loss: 0.0125 - precision: 0.7830 - recall: 0.3063 - val_loss: 0.0125 - val_precision: 0.7915 - val_recall: 0.3007
# Epoch 2/25
# 2498/2498 [==============================] - 311s 124ms/step - loss: 0.0117 - precision: 0.8021 - recall: 0.3368 - val_loss: 0.0125 - val_precision: 0.7796 - val_recall: 0.3143
# Epoch 3/25
# 2498/2498 [==============================] - 311s 124ms/step - loss: 0.0112 - precision: 0.8078 - recall: 0.3536 - val_loss: 0.0126 - val_precision: 0.7547 - val_recall: 0.3311

# %%
model.save(DATA_PATH + 'CNN3LayerRegularSet3.h5')

# %% [markdown]
# ### Set 4

# %%
import gzip
import pickle as pkl
import gc

import numpy as np

DATA_DIR = mypath + "/data/"

DATA_PATH = DATA_DIR + "preprocessed_3004/"
DATA_NPZ_FILE = f'{DATA_PATH}dataTrainValTestSet4.npz'

print ('reading from saved file: ', DATA_NPZ_FILE)
data = np.load(DATA_NPZ_FILE)
lst = data.files
for item in lst:
    print(item)

print("done")
x_train_load = data['x_train']
x_val_load = data['x_val']
# x_test = data['x_test']

x_train = x_train_load
x_val = x_val_load
# x_test = x_test

del x_train_load
del x_val_load

print('x_train: ' , x_train.shape)
print('x_val: ', x_val.shape)
# print('x_test: ', x_test.shape)

# rol_y_train = data['rol_y_train']
# rol_y_val = data['rol_y_val']
# rol_y_test = data['rol_y_test']

# print('rol_y_train: ', rol_y_train.shape)
# print('rol_y_val: ', rol_y_val.shape)
# print('rol_y_test: ', rol_y_test.shape)

# y_train = rol_y_train
# y_val = rol_y_val
# y_test = rol_y_test


reg_y_train = data['reg_y_train']
reg_y_val = data['reg_y_val']
# reg_y_test = data['reg_y_test']


y_train = reg_y_train
y_val = reg_y_val
# y_test = reg_y_test

print('y_train: ', y_train.shape)
print('y_val: ', y_val.shape)
# print('reg_y_test: ', reg_y_test.shape)

del data
del lst
del reg_y_train
del reg_y_val
# del reg_y_test


with open(DATA_PATH + 'row_index_dictionary.p', 'rb') as f:
    word_index = pkl.load(f)
    print("Got word index")

embedding_matrix = np.load(DATA_PATH + 'embedding_matrix.p', allow_pickle=True)

gc.collect()
# Out:
# reading from saved file:  drive/My Drive/CS598DLHProject/data/preprocessed_3004/dataTrainValTestSet4.npz
# x_train
# x_val
# x_test
# reg_y_train
# reg_y_val
# reg_y_test
# rol_y_train
# rol_y_val
# rol_y_test
# done
# x_train:  (15985, 2199)
# x_val:  (12788, 2199)
# y_train:  (15985, 4103)
# y_val:  (12788, 4103)
# Got word index
# 1627

# %%
from tensorflow.keras.callbacks import Callback
# from sklearn.metrics import precision_score, recall_score, f1_score
import numpy as np
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Embedding, Dense, GlobalAveragePooling1D, Conv1D, ReLU
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import backend as k
import keras
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Embedding, Dense, Conv1D, GlobalMaxPooling1D, concatenate

class GarbageCollectorCallback(Callback):
    def on_epoch_end(self, epoch, logs=None):
        gc.collect()
        k.clear_session()


model = load_model(DATA_PATH + 'CNN3LayerRegularSet3.h5')

early_stopping = EarlyStopping(min_delta=.0001, patience=2)
garbage_collection = GarbageCollectorCallback()
model.fit(x_train, y_train,
          batch_size=32, epochs=25,
          validation_data=[x_val, y_val],
          callbacks=[early_stopping, garbage_collection])
# Out:
# Epoch 1/25
# 500/500 [==============================] - 75s 150ms/step - loss: 0.0124 - precision: 0.7845 - recall: 0.3159 - val_loss: 0.0124 - val_precision: 0.7891 - val_recall: 0.3172
# Epoch 2/25
# 500/500 [==============================] - 74s 147ms/step - loss: 0.0111 - precision: 0.8277 - recall: 0.3615 - val_loss: 0.0125 - val_precision: 0.7790 - val_recall: 0.3263
# Epoch 3/25
# 500/500 [==============================] - 74s 147ms/step - loss: 0.0104 - precision: 0.8412 - recall: 0.3927 - val_loss: 0.0128 - val_precision: 0.7605 - val_recall: 0.3285

# %%
model.save(DATA_PATH + 'CNN3LayerRegularSet4.h5')
